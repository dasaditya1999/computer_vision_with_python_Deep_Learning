# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
l = [1,2,3,3]
if 3 in l:
    print(l.index(3,2+1))
# Out:
# 3

# %%
for i, j in enumerate(l):
    print(i,j)
# Out:
# 0 1
# 1 2
# 2 3

# %%
cap = cv2.VideoCapture(1)
cap.get()
# Out:
# OpenCV: out device of bound (0-0): 1
# OpenCV: camera failed to properly initialize!
# < cv2.VideoCapture 0x15efced50>

# %%
cv2.EVENT_RBUTTONDOWN
cv2.EVENT_FLAG_MBUTTON

# %%
img = np.zeros(shape=(715,712,3), dtype=np.int16)

### Some Functions like draw circle, draw rectangle, draw lines, draw polylines ###
def drawCircle(event, x, y, flags, params):
    if event == cv2.EVENT_LBUTTONDOWN:
        cv2.circle(img, (x,y), 100, (255,0,255), -1)

cv2.namedWindow(winname='blank_image')

cv2.setMouseCallback('blank_image',drawCircle)

def drawRectangle():
    pass

def drawpolylines():
    pass


while True:
    cv2.imshow('blank_image',img)

    if cv2.waitKey(5) & 0xFF==27:
        break;

cv2.destroyAllWindows()

# %%
plt.imshow(img)

# %%
np.ones(shape=(512,512,3), dtype=np.uint8).max()
# Out:
# 1

# %%
arr = np.random.randint(0,255, (512,512,3), dtype=np.uint8)

# %%
plt.imshow(arr)

# %%
cv2.circle(arr,center=(200,200),radius=10, color=(255,0,0), thickness=3)
# Out:
# array([[[102, 111, 250],
#         [208,  46, 116],
#         [ 22, 220, 116],
#         ...,
#         [ 43,  24,  35],
#         [195,  91, 223],
#         [ 69, 122,  28]],
#
#        [[193, 134, 150],
#         [ 43, 105, 194],
#         [ 46,  94,  38],
#         ...,
#         [ 13, 204, 233],
#         [189,  99, 160],
#         [122, 251, 184]],
#
#        [[100, 220, 204],
#         [ 12, 188, 229],
#         [ 11,  41, 226],
#         ...,
#         [200, 141,  19],
#         [ 42, 130,  18],
#         [  9,  59, 149]],
#
#        ...,
#
#        [[121, 248, 157],
#         [238,  98,  48],
#         [ 15,  65,  99],
#         ...,
#         [ 11, 142, 218],
#         [159, 162, 199],
#         [ 90, 100, 209]],
#
#        [[ 85, 239,  30],
#         [ 88,  34, 228],
#         [ 92,  10,  29],
#         ...,
#         [169, 162,  24],
#         [ 46, 139,  22],
#         [227,  55,  81]],
#
#        [[168, 101, 200],
#         [ 60, 220, 190],
#         [240, 158,  19],
# ...

# %%
plt.imshow(arr)

# %%
np.random.randint()

# %%
plt.imshow(np.random.rand(523,523,3).astype('uint8'))

# %%
cv2.EVENT_RBUTTONDOWN

# %%
cv2.EVENT_M

# %%
tup = ()
print(id(tup))
tup=(1,2)
print(tup)
id(tup)
# Out:
# 4370646936
# (1, 2)
# 6049739648

# %%
b = []
def a():
    b.append(100)
    print(b)
a()
# Out:
# [100]

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
img = cv2.imread('invoice.jpg')
rgb_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(rgb_img)

# %%
# img[0:10,0:5]

# %%
pt1 = (511, 108)
pt2 = (667, 142)

# %%
rgb_img.shape
# Out:
# (1124, 700, 3)

# %%
plt.imshow(rgb_img[pt1[1]:pt2[1], pt1[0]:pt2[0]])

# %%
plt.imsave('sub_invoice.jpg',rgb_img[pt1[1]:pt2[1], pt1[0]:pt2[0]])

# %%
# plt.imshow(np.ones(shape=(712,712,3), dtype=np.uint8)*0)

# %% [markdown]
# All 0 = Black,
# All 255 = White

# %%
# rgb_img[pt1[1]:pt2[1], pt1[0]:pt2[0]].mean()

# %%
Threedim = np.random.randint(low=0,high=100,size=(3,10,2))
Threedim
# Out:
# array([[[15, 38],
#         [34, 72],
#         [36, 98],
#         [29, 92],
#         [ 4, 81],
#         [25, 66],
#         [93, 60],
#         [11, 22],
#         [ 5, 84],
#         [73, 19]],
#
#        [[95, 11],
#         [82, 47],
#         [ 6, 62],
#         [31, 55],
#         [89, 42],
#         [63, 45],
#         [78, 57],
#         [54,  0],
#         [61, 90],
#         [13, 62]],
#
#        [[72,  4],
#         [11, 94],
#         [98, 86],
#         [ 3, 91],
#         [29, 90],
#         [95, 70],
#         [45, 44],
#         [59,  6],
#         [97, 47],
#         [87, 64]]])

# %%
Threedim.shape
# Out:
# (3, 10, 2)

# %%
img = cv2.imread('invoice.jpg')
img.shape
# Out:
# (1124, 700, 3)

# %%
img[:,:,0].shape
# Out:
# (1124, 700)

# %%
plt.imshow(img[:,:,2])
