# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

import cv2

# %%
pwd
# Out:
# '/Users/adityanarayandas/Downloads/Aditya_Computer_Vision_Revisit'

# %%
image = cv2.imread('CATS_DOGS/train/CAT/4.jpg')
image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(image)

# %% [markdown]
# ### Preparing the Dataset for the Model Training
# #### We can make our data more variety to make the Model Robust while getting the real-time images for prediction

# %% [markdown]
# #### We can use the ImageDataGenartor functionality of the Keras library

# %%
from keras.preprocessing.image import ImageDataGenerator
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 from keras.preprocessing.image import ImageDataGenerator
#
# File ~/anaconda3/lib/python3.11/site-packages/keras/__init__.py:21
#      15 """Implementation of the Keras API, the high-level API of TensorFlow.
#      16
#      17 Detailed documentation and user guides are available at
#      18 [keras.io](https://keras.io).
#      19 """
#      20 from keras import distribute
# ---> 21 from keras import models
#      22 from keras.engine.input_layer import Input
#      23 from keras.engine.sequential import Sequential
#
# File ~/anaconda3/lib/python3.11/site-packages/keras/models/__init__.py:18
#       1 # Copyright 2022 The TensorFlow Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
# ...

# %%
pip show tensorflow
# Out:
# Name: tensorflow
# Version: 2.14.0
# Summary: TensorFlow is an open source machine learning framework for everyone.
# Home-page: https://www.tensorflow.org/
# Author: Google Inc.
# Author-email: packages@tensorflow.org
# License: Apache 2.0
# Location: /Users/adityanarayandas/anaconda3/lib/python3.11/site-packages
# Requires: tensorflow-macos
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
pip show keras
# Out:
# Name: keras
# Version: 2.14.0
# Summary: Deep learning for humans.
# Home-page: https://keras.io/
# Author: Keras team
# Author-email: keras-users@googlegroups.com
# License: Apache 2.0
# Location: /Users/adityanarayandas/anaconda3/lib/python3.11/site-packages
# Requires:
# Required-by: keras-utils, tensorflow-macos
# Note: you may need to restart the kernel to use updated packages.

# %%
from tensorflow import keras
