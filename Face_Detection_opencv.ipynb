# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pwd
# Out:
# '/Users/adityanarayandas/Downloads/Aditya_Computer_Vision_Revisit'

# %%
denis = cv2.imread('Denis_Mukwege.jpg', 0)
nadia = cv2.imread('Nadia_Murad.jpg',0)
solvay = cv2.imread('solvay_conference.jpg',0)

# %%
plt.imshow(solvay, cmap='gray')

# %% [markdown]
# ## CaseCade Files

# %% [markdown]
# #### opencv comes with various cascade files which are already trained on various data to perform various tasks

# %% [markdown]
# ## Face Detection

# %%
face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

# %%
def detect_face(image):
    image_copy = image.copy()

    face_rectangle_list = face_cascade.detectMultiScale(image_copy)

    while True:
        
        for x,y,w,h in face_rectangle_list:
            cv2.rectangle(image_copy, (x,y), (x+w,y+h), (255,0,0), 4)
        
    plt.imshow(image_copy, cmap='gray')
    
# cv2.destroyAllWindows()

# %%
detect_face(denis)
# plt.imshow(result, cmap='gray')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 detect_face(denis)
#       2 # plt.imshow(result, cmap='gray')
#
# Cell In[6], line 9, in detect_face(image)
#       6 while True:
#       8     for x,y,w,h in face_rectangle_list:
# ----> 9         cv2.rectangle(image_copy, (x,y), (x+w,y+h), (255,0,0), 4)
#      11 plt.imshow(image_copy, cmap='gray')
#
# KeyboardInterrupt:
